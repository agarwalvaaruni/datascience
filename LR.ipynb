# %% [markdown]
# # Task - 1: Predict the percentage of an student based on the no. of study hours

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('http://bit.ly/w-data')
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
plt.plot(df['Hours'],df['Scores'],'o')
plt.xlabel('No. of Hours')
plt.ylabel('Percentage Scored')
plt.title('No. of Hours studied vs Percentage Scored')
plt.show()

# %%
df.corr()
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %% [markdown]
# ### We get to see a Linear Relationship between the number of hours and scores. Thus Linear Regression can be used for this purpose.

# %%
x = df[['Hours']]
y = df['Scores']

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
print('Training the Model...')
# Out:
# Training the Model...

# %%
lr.coef_
# Out:
# array([9.91065648])

# %%
lr.intercept_
# Out:
# 2.0181600414346974

# %%
line=lr.intercept_+x*lr.coef_

plt.scatter(x,y)
plt.plot(x,line)
plt.show()

# %%
y_pred = lr.predict(x_test)

# %%
d = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
d
# Out:
#     Actual  Predicted
# 5       20  16.884145
# 2       27  33.732261
# 19      69  75.357018
# 16      30  26.794801
# 11      62  60.491033

# %%
hours = [[9.25]]
own_pred = lr.predict(hours)
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = [[9.25]]
# Predicted Score = 93.69173248737535

# %%
from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002975
